# %%
import pandas as pd

# %%
def CleanData(dataFrame:pd.DataFrame):
    #Make sure what was passed in is a dataframe so we can use functions like drop and get_dummies
    if type(dataFrame) != pd.DataFrame:
        raise RuntimeError("that is not a data frame")
    dataFrame.drop(columns={"Datasource", "Data_Value_Unit", "GeoLocation", "Data_Value_Type", "Low_Confidence_Limit", "Low_Confidence_Limit"}, inplace=True)
    return pd.DataFrame(dataFrame)

# %%
df = pd.read_csv("Nutrition__Physical_Activity__and_Obesity_-_Behavioral_Risk_Factor_Surveillance_System.csv")
df = CleanData(df)
df.sample(10)
#print(df.Class.value_counts(), df.Topic.value_counts())
# Out:
#        YearStart  YearEnd LocationAbbr          LocationDesc  \
# 26070       2013     2013           OR                Oregon
# 3514        2011     2011           CO              Colorado
# 20127       2013     2013           NV                Nevada
# 46179       2015     2015           DE              Delaware
# 8178        2011     2011           ID                 Idaho
# 42953       2015     2015           NC        North Carolina
# 6012        2014     2014           DC  District of Columbia
# 29529       2013     2013           TN             Tennessee
# 51261       2016     2016           NY              New York
# 40909       2015     2015           ME                 Maine
#
#                          Class                             Topic  \
# 26070    Fruits and Vegetables  Fruits and Vegetables - Behavior
# 3514         Physical Activity      Physical Activity - Behavior
# 20127        Physical Activity      Physical Activity - Behavior
# 46179  Obesity / Weight Status           Obesity / Weight Status
# 8178   Obesity / Weight Status           Obesity / Weight Status
# 42953        Physical Activity      Physical Activity - Behavior
# 6012   Obesity / Weight Status           Obesity / Weight Status
# 29529    Fruits and Vegetables  Fruits and Vegetables - Behavior
# 51261  Obesity / Weight Status           Obesity / Weight Status
# 40909        Physical Activity      Physical Activity - Behavior
#
#                                                 Question  Data_Value  \
# 26070  Percent of adults who report consuming vegetab...        16.3
# 3514   Percent of adults who achieve at least 150 min...         NaN
# 20127  Percent of adults who engage in muscle-strengt...        33.1
# 46179  Percent of adults aged 18 years and older who ...        40.6
# 8178   Percent of adults aged 18 years and older who ...         NaN
# 42953  Percent of adults who engage in no leisure-tim...        25.1
# 6012   Percent of adults aged 18 years and older who ...        25.9
# 29529  Percent of adults who report consuming fruit l...        47.2
# 51261  Percent of adults aged 18 years and older who ...        30.3
# 40909  Percent of adults who achieve at least 150 min...        15.5
#
#        Data_Value_Alt Data_Value_Footnote_Symbol  ...  \
# 26070            16.3                        NaN  ...
# 3514              NaN                          ~  ...
# 20127            33.1                        NaN  ...
# 46179            40.6                        NaN  ...
# 8178              NaN                          ~  ...
# 42953            25.1                        NaN  ...
# 6012             25.9                        NaN  ...
# 29529            47.2                        NaN  ...
# 51261            30.3                        NaN  ...
# 40909            15.5                        NaN  ...
#
#                   Race/Ethnicity  ClassID  TopicID QuestionID DataValueTypeID  \
# 26070                        NaN       FV      FV1       Q019           VALUE
# 3514   Hawaiian/Pacific Islander       PA      PA1       Q043           VALUE
# 20127                        NaN       PA      PA1       Q046           VALUE
# 46179                        NaN      OWS     OWS1       Q037           VALUE
# 8178          Non-Hispanic Black      OWS     OWS1       Q036           VALUE
# 42953                        NaN       PA      PA1       Q047           VALUE
# 6012                         NaN      OWS     OWS1       Q037           VALUE
# 29529                        NaN       FV      FV1       Q018           VALUE
# 51261                        NaN      OWS     OWS1       Q036           VALUE
# 40909                        NaN       PA      PA1       Q044           VALUE
#
#       LocationID StratificationCategory1            Stratification1  \
# 26070         41                   Total                      Total
# 3514           8          Race/Ethnicity  Hawaiian/Pacific Islander
# 20127         32                  Income          $35,000 - $49,999
# 46179         10             Age (years)                    35 - 44
# 8178          16          Race/Ethnicity         Non-Hispanic Black
# 42953         37                  Gender                       Male
# 6012          11             Age (years)                    18 - 24
# 29529         47             Age (years)                    55 - 64
# 51261         36               Education       High school graduate
# 40909         23                  Income          Data not reported
#
#       StratificationCategoryId1 StratificationID1
# 26070                       OVR           OVERALL
# 3514                       RACE           RACEHPI
# 20127                       INC           INC3550
# 46179                     AGEYR         AGEYR3544
# 8178                       RACE           RACEBLK
# 42953                       GEN              MALE
# 6012                      AGEYR         AGEYR1824
# 29529                     AGEYR         AGEYR5564
# 51261                       EDU         EDUHSGRAD
# 40909                       INC             INCNR
#
# [10 rows x 28 columns]

# %%
print(df.columns)
# Out:
# Index(['YearStart', 'YearEnd', 'LocationAbbr', 'LocationDesc', 'Class',
#        'Topic', 'Question', 'Data_Value', 'Data_Value_Alt',
#        'Data_Value_Footnote_Symbol', 'Data_Value_Footnote',
#        'High_Confidence_Limit ', 'Sample_Size', 'Total', 'Age(years)',
#        'Education', 'Gender', 'Income', 'Race/Ethnicity', 'ClassID', 'TopicID',
#        'QuestionID', 'DataValueTypeID', 'LocationID',
#        'StratificationCategory1', 'Stratification1',
#        'StratificationCategoryId1', 'StratificationID1'],
#       dtype='object')

# %%
df["High_Confidence_Limit "].value_counts()
# Out:
# 37.1    222
# 37.8    218
# 37.9    217
# 37.2    212
# 35.6    209
#        ...
# 73.1      1
# 73.0      1
# 7.7       1
# 5.7       1
# 8.7       1
# Name: High_Confidence_Limit , Length: 723, dtype: int64

# %%
df["StratificationCategory1"].value_counts()
# Out:
# Race/Ethnicity    15256
# Income            13349
# Age (years)       11438
# Education          7628
# Gender             3814
# Total              1907
# Name: StratificationCategory1, dtype: int64

# %%
dfRace = df[df["StratificationCategory1"] == "Race/Ethnicity"]
dfIncome = df[df["StratificationCategory1"] == "Income"]
dfAge = df[df["StratificationCategory1"] == "Age (years)"]
dfEducation = df[df["StratificationCategory1"] == "Education"]
dfGender = df[df["StratificationCategory1"] == "Gender"]
dfTotals = df[df["StratificationCategory1"] == "Total"]

# %%
dfTotals.head()
# Out:
#      YearStart  YearEnd LocationAbbr LocationDesc                    Class  \
# 0         2011     2011           AL      Alabama  Obesity / Weight Status
# 28        2011     2011           AL      Alabama  Obesity / Weight Status
# 56        2011     2011           AL      Alabama    Fruits and Vegetables
# 84        2011     2011           AL      Alabama    Fruits and Vegetables
# 113       2011     2011           AL      Alabama        Physical Activity
#
#                                 Topic  \
# 0             Obesity / Weight Status
# 28            Obesity / Weight Status
# 56   Fruits and Vegetables - Behavior
# 84   Fruits and Vegetables - Behavior
# 113      Physical Activity - Behavior
#
#                                               Question  Data_Value  \
# 0    Percent of adults aged 18 years and older who ...        32.0
# 28   Percent of adults aged 18 years and older who ...        34.7
# 56   Percent of adults who report consuming fruit l...        43.8
# 84   Percent of adults who report consuming vegetab...        24.3
# 113  Percent of adults who achieve at least 150 min...        42.4
#
#      Data_Value_Alt Data_Value_Footnote_Symbol  ... Race/Ethnicity  ClassID  \
# 0              32.0                        NaN  ...            NaN      OWS
# 28             34.7                        NaN  ...            NaN      OWS
# 56             43.8                        NaN  ...            NaN       FV
# 84             24.3                        NaN  ...            NaN       FV
# 113            42.4                        NaN  ...            NaN       PA
#
#      TopicID QuestionID DataValueTypeID LocationID StratificationCategory1  \
# 0       OWS1       Q036           VALUE          1                   Total
# 28      OWS1       Q037           VALUE          1                   Total
# 56       FV1       Q018           VALUE          1                   Total
# 84       FV1       Q019           VALUE          1                   Total
# 113      PA1       Q043           VALUE          1                   Total
#
#     Stratification1 StratificationCategoryId1 StratificationID1
# 0             Total                       OVR           OVERALL
# 28            Total                       OVR           OVERALL
# 56            Total                       OVR           OVERALL
# 84            Total                       OVR           OVERALL
# 113           Total                       OVR           OVERALL
#
# [5 rows x 28 columns]
